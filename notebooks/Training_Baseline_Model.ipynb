# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data

data_path = "/content/final_data.csv"

df = pd.read_csv(data_path, parse_dates=["tpep_pickup_datetime"])

# %%
df
# Out:
#        tpep_pickup_datetime  region  total_pickups  avg_pickups
# 0       2016-01-01 00:00:00       0           13.0         13.0
# 1       2016-01-01 00:15:00       0           10.0         11.0
# 2       2016-01-01 00:30:00       0           10.0         11.0
# 3       2016-01-01 00:45:00       0           10.0         10.0
# 4       2016-01-01 01:00:00       0           10.0         10.0
# ...                     ...     ...            ...          ...
# 171273  2016-02-22 01:45:00      25           10.0         10.0
# 171274  2016-02-22 02:00:00      25           10.0         10.0
# 171275  2016-02-22 02:15:00      25           10.0         10.0
# 171276  2016-02-22 02:30:00      25           10.0         10.0
# 171277  2016-02-22 02:45:00       2            NaN          NaN
#
# [171278 rows x 4 columns]

# %%
# shape of the data

df.shape
# Out:
# (171278, 4)

# %%
# datatypes

df.dtypes
# Out:
# tpep_pickup_datetime    datetime64[ns]
# region                           int64
# total_pickups                  float64
# avg_pickups                    float64
# dtype: object

# %%
# check for missing values

df.isna().sum()
# Out:
# tpep_pickup_datetime    0
# region                  0
# total_pickups           1
# avg_pickups             1
# dtype: int64

# %%
# extract the day of week information
df["day_of_week"] = df["tpep_pickup_datetime"].dt.day_of_week

# extract the month information
df["month"] = df["tpep_pickup_datetime"].dt.month

# %%
# set the datetime column as index

df.set_index("tpep_pickup_datetime", inplace=True)

# %%
df
# Out:
#                       region  total_pickups  avg_pickups  day_of_week  month
# tpep_pickup_datetime
# 2016-01-01 00:00:00        0           13.0         13.0            4      1
# 2016-01-01 00:15:00        0           10.0         11.0            4      1
# 2016-01-01 00:30:00        0           10.0         11.0            4      1
# 2016-01-01 00:45:00        0           10.0         10.0            4      1
# 2016-01-01 01:00:00        0           10.0         10.0            4      1
# ...                      ...            ...          ...          ...    ...
# 2016-02-22 01:45:00       25           10.0         10.0            0      2
# 2016-02-22 02:00:00       25           10.0         10.0            0      2
# 2016-02-22 02:15:00       25           10.0         10.0            0      2
# 2016-02-22 02:30:00       25           10.0         10.0            0      2
# 2016-02-22 02:45:00        2            NaN          NaN            0      2
#
# [171278 rows x 5 columns]

# %%
# create the region grouper

region_grp = df.groupby("region")

region_grp

# %%
# shifting periods

periods = list(range(1,5))

periods
# Out:
# [1, 2, 3, 4]

# %%
# generate the lag features

lag_features = region_grp["total_pickups"].shift(periods)

lag_features
# Out:
#                       total_pickups_1  total_pickups_2  total_pickups_3  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00              13.0              NaN              NaN
# 2016-01-01 00:30:00              10.0             13.0              NaN
# 2016-01-01 00:45:00              10.0             10.0             13.0
# 2016-01-01 01:00:00              10.0             10.0             10.0
# ...                               ...              ...              ...
# 2016-02-22 01:45:00              10.0             10.0             10.0
# 2016-02-22 02:00:00              10.0             10.0             10.0
# 2016-02-22 02:15:00              10.0             10.0             10.0
# 2016-02-22 02:30:00              10.0             10.0             10.0
# 2016-02-22 02:45:00              59.0             48.0             21.0
#
#                       total_pickups_4
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN
# 2016-01-01 00:15:00               NaN
# 2016-01-01 00:30:00               NaN
# 2016-01-01 00:45:00               NaN
# 2016-01-01 01:00:00              13.0
# ...                               ...
# 2016-02-22 01:45:00              10.0
# 2016-02-22 02:00:00              10.0
# 2016-02-22 02:15:00              10.0
# 2016-02-22 02:30:00              10.0
# 2016-02-22 02:45:00              10.0
#
# [171278 rows x 4 columns]

# %%
# merge them with the original df

data = pd.concat([lag_features,df],axis=1)

data
# Out:
#                       total_pickups_1  total_pickups_2  total_pickups_3  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN              NaN              NaN
# 2016-01-01 00:15:00              13.0              NaN              NaN
# 2016-01-01 00:30:00              10.0             13.0              NaN
# 2016-01-01 00:45:00              10.0             10.0             13.0
# 2016-01-01 01:00:00              10.0             10.0             10.0
# ...                               ...              ...              ...
# 2016-02-22 01:45:00              10.0             10.0             10.0
# 2016-02-22 02:00:00              10.0             10.0             10.0
# 2016-02-22 02:15:00              10.0             10.0             10.0
# 2016-02-22 02:30:00              10.0             10.0             10.0
# 2016-02-22 02:45:00              59.0             48.0             21.0
#
#                       total_pickups_4  region  total_pickups  avg_pickups  \
# tpep_pickup_datetime
# 2016-01-01 00:00:00               NaN       0           13.0         13.0
# 2016-01-01 00:15:00               NaN       0           10.0         11.0
# 2016-01-01 00:30:00               NaN       0           10.0         11.0
# 2016-01-01 00:45:00               NaN       0           10.0         10.0
# 2016-01-01 01:00:00              13.0       0           10.0         10.0
# ...                               ...     ...            ...          ...
# 2016-02-22 01:45:00              10.0      25           10.0         10.0
# 2016-02-22 02:00:00              10.0      25           10.0         10.0
# 2016-02-22 02:15:00              10.0      25           10.0         10.0
# 2016-02-22 02:30:00              10.0      25           10.0         10.0
# 2016-02-22 02:45:00              10.0       2            NaN          NaN
#
#                       day_of_week  month
# tpep_pickup_datetime
# 2016-01-01 00:00:00             4      1
# 2016-01-01 00:15:00             4      1
# 2016-01-01 00:30:00             4      1
# 2016-01-01 00:45:00             4      1
# 2016-01-01 01:00:00             4      1
# ...                           ...    ...
# 2016-02-22 01:45:00             0      2
# 2016-02-22 02:00:00             0      2
# 2016-02-22 02:15:00             0      2
# 2016-02-22 02:30:00             0      2
# 2016-02-22 02:45:00             0      2
#
# [171278 rows x 9 columns]

# %%
print("The shape of the df before merger ", df.shape)
print("The shape of the df after merger ", data.shape)
# Out:
# The shape of the df before merger  (171278, 5)
# The shape of the df after merger  (171278, 9)

# %%
# rows having missing values

data.isna().any(axis=1).sum()
# Out:
# np.int64(105)

# %%
# drop the missing values

data.dropna(inplace=True)

# %%
data.isna().any(axis=1).sum()
# Out:
# np.int64(0)

# %%
mapper = {name:f"lag_{ind+1}" for ind, name in enumerate(data.columns[0:4])}

mapper
# Out:
# {'total_pickups_1': 'lag_1',
#  'total_pickups_2': 'lag_2',
#  'total_pickups_3': 'lag_3',
#  'total_pickups_4': 'lag_4'}

# %%
# replace the column names

data = data.rename(columns=mapper)

# %%
data.head()
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  total_pickups  \
# tpep_pickup_datetime
# 2016-01-01 01:00:00    10.0   10.0   10.0   13.0       0           10.0
# 2016-01-01 01:15:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:30:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:45:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 02:00:00    10.0   10.0   10.0   10.0       0           10.0
#
#                       avg_pickups  day_of_week  month
# tpep_pickup_datetime
# 2016-01-01 01:00:00          10.0            4      1
# 2016-01-01 01:15:00          10.0            4      1
# 2016-01-01 01:30:00          10.0            4      1
# 2016-01-01 01:45:00          10.0            4      1
# 2016-01-01 02:00:00          10.0            4      1

# %%
# shape of the data

data.shape
# Out:
# (171173, 9)

# %%
# number of rows in each month

data['month'].value_counts()
# Out:
# month
# 1    77173
# 2    71627
# 3    22373
# Name: count, dtype: int64

# %%
data
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  total_pickups  \
# tpep_pickup_datetime
# 2016-01-01 01:00:00    10.0   10.0   10.0   13.0       0           10.0
# 2016-01-01 01:15:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:30:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:45:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 02:00:00    10.0   10.0   10.0   10.0       0           10.0
# ...                     ...    ...    ...    ...     ...            ...
# 2016-02-22 01:30:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 01:45:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:00:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:15:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:30:00    10.0   10.0   10.0   10.0      25           10.0
#
#                       avg_pickups  day_of_week  month
# tpep_pickup_datetime
# 2016-01-01 01:00:00          10.0            4      1
# 2016-01-01 01:15:00          10.0            4      1
# 2016-01-01 01:30:00          10.0            4      1
# 2016-01-01 01:45:00          10.0            4      1
# 2016-01-01 02:00:00          10.0            4      1
# ...                           ...          ...    ...
# 2016-02-22 01:30:00          10.0            0      2
# 2016-02-22 01:45:00          10.0            0      2
# 2016-02-22 02:00:00          10.0            0      2
# 2016-02-22 02:15:00          10.0            0      2
# 2016-02-22 02:30:00          10.0            0      2
#
# [171173 rows x 9 columns]

# %%
data.loc[data["month"].isin([1,2]),"lag_1":"day_of_week"]
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  total_pickups  \
# tpep_pickup_datetime
# 2016-01-01 01:00:00    10.0   10.0   10.0   13.0       0           10.0
# 2016-01-01 01:15:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:30:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:45:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 02:00:00    10.0   10.0   10.0   10.0       0           10.0
# ...                     ...    ...    ...    ...     ...            ...
# 2016-02-22 01:30:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 01:45:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:00:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:15:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:30:00    10.0   10.0   10.0   10.0      25           10.0
#
#                       avg_pickups  day_of_week
# tpep_pickup_datetime
# 2016-01-01 01:00:00          10.0            4
# 2016-01-01 01:15:00          10.0            4
# 2016-01-01 01:30:00          10.0            4
# 2016-01-01 01:45:00          10.0            4
# 2016-01-01 02:00:00          10.0            4
# ...                           ...          ...
# 2016-02-22 01:30:00          10.0            0
# 2016-02-22 01:45:00          10.0            0
# 2016-02-22 02:00:00          10.0            0
# 2016-02-22 02:15:00          10.0            0
# 2016-02-22 02:30:00          10.0            0
#
# [148800 rows x 8 columns]

# %%
# Assuming 'data' is your dataset, and it includes the necessary columns like 'month', 'lag_1', and 'day_of_week'

# Split the data into training and testing sets
trainset = data.loc[data["month"].isin([1, 2]), "lag_1":"day_of_week"]
testset = data.loc[data["month"].isin([3]), "lag_1":"day_of_week"]

# %%
trainset
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  total_pickups  \
# tpep_pickup_datetime
# 2016-01-01 01:00:00    10.0   10.0   10.0   13.0       0           10.0
# 2016-01-01 01:15:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:30:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 01:45:00    10.0   10.0   10.0   10.0       0           10.0
# 2016-01-01 02:00:00    10.0   10.0   10.0   10.0       0           10.0
# ...                     ...    ...    ...    ...     ...            ...
# 2016-02-22 01:30:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 01:45:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:00:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:15:00    10.0   10.0   10.0   10.0      25           10.0
# 2016-02-22 02:30:00    10.0   10.0   10.0   10.0      25           10.0
#
#                       avg_pickups  day_of_week
# tpep_pickup_datetime
# 2016-01-01 01:00:00          10.0            4
# 2016-01-01 01:15:00          10.0            4
# 2016-01-01 01:30:00          10.0            4
# 2016-01-01 01:45:00          10.0            4
# 2016-01-01 02:00:00          10.0            4
# ...                           ...          ...
# 2016-02-22 01:30:00          10.0            0
# 2016-02-22 01:45:00          10.0            0
# 2016-02-22 02:00:00          10.0            0
# 2016-02-22 02:15:00          10.0            0
# 2016-02-22 02:30:00          10.0            0
#
# [148800 rows x 8 columns]

# %%
# Save the train and test data
train_data_save_path = "/content/df_final_train.csv"  # Save path for trainset
test_data_save_path = "/content/df_final_test.csv"    # Save path for testset

# Save the DataFrames as CSV files
trainset.to_csv(train_data_save_path, index=True)
testset.to_csv(test_data_save_path, index=True)

# Print confirmation for saved paths
print(f"Training data saved to: {train_data_save_path}")
print(f"Test data saved to: {test_data_save_path}")
# Out:
# Training data saved to: /content/df_final_train.csv
# Test data saved to: /content/df_final_test.csv

# %%
# make X_train and y_train

X_train = trainset.drop(columns=["total_pickups"])

y_train = trainset["total_pickups"]

# %%
X_train.shape
# Out:
# (148800, 7)

# %%
X_train
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  avg_pickups  \
# tpep_pickup_datetime
# 2016-01-01 01:00:00    10.0   10.0   10.0   13.0       0         10.0
# 2016-01-01 01:15:00    10.0   10.0   10.0   10.0       0         10.0
# 2016-01-01 01:30:00    10.0   10.0   10.0   10.0       0         10.0
# 2016-01-01 01:45:00    10.0   10.0   10.0   10.0       0         10.0
# 2016-01-01 02:00:00    10.0   10.0   10.0   10.0       0         10.0
# ...                     ...    ...    ...    ...     ...          ...
# 2016-02-22 01:30:00    10.0   10.0   10.0   10.0      25         10.0
# 2016-02-22 01:45:00    10.0   10.0   10.0   10.0      25         10.0
# 2016-02-22 02:00:00    10.0   10.0   10.0   10.0      25         10.0
# 2016-02-22 02:15:00    10.0   10.0   10.0   10.0      25         10.0
# 2016-02-22 02:30:00    10.0   10.0   10.0   10.0      25         10.0
#
#                       day_of_week
# tpep_pickup_datetime
# 2016-01-01 01:00:00             4
# 2016-01-01 01:15:00             4
# 2016-01-01 01:30:00             4
# 2016-01-01 01:45:00             4
# 2016-01-01 02:00:00             4
# ...                           ...
# 2016-02-22 01:30:00             0
# 2016-02-22 01:45:00             0
# 2016-02-22 02:00:00             0
# 2016-02-22 02:15:00             0
# 2016-02-22 02:30:00             0
#
# [148800 rows x 7 columns]

# %%
y_train
# Out:
# tpep_pickup_datetime
# 2016-01-01 01:00:00    10.0
# 2016-01-01 01:15:00    10.0
# 2016-01-01 01:30:00    10.0
# 2016-01-01 01:45:00    10.0
# 2016-01-01 02:00:00    10.0
#                        ...
# 2016-02-22 01:30:00    10.0
# 2016-02-22 01:45:00    10.0
# 2016-02-22 02:00:00    10.0
# 2016-02-22 02:15:00    10.0
# 2016-02-22 02:30:00    10.0
# Name: total_pickups, Length: 148800, dtype: float64

# %%
# make X_test and y_test

X_test = testset.drop(columns=["total_pickups"])

y_test = testset["total_pickups"]

# %%
X_test.shape
# Out:
# (22373, 7)

# %%
X_test
# Out:
#                       lag_1  lag_2  lag_3  lag_4  region  avg_pickups  \
# tpep_pickup_datetime
# 2016-03-01 00:00:00    10.0   10.0   10.0   10.0       0         10.0
# 2016-03-01 00:15:00    11.0   10.0   10.0   10.0       0         10.0
# 2016-03-01 00:30:00    10.0   11.0   10.0   10.0       0         10.0
# 2016-03-01 00:45:00    10.0   10.0   11.0   10.0       0         10.0
# 2016-03-01 01:00:00    10.0   10.0   10.0   11.0       0         10.0
# ...                     ...    ...    ...    ...     ...          ...
# 2016-03-10 06:30:00    10.0   10.0   10.0   10.0      24         10.0
# 2016-03-10 06:45:00    10.0   10.0   10.0   10.0      24         10.0
# 2016-03-10 07:00:00    10.0   10.0   10.0   10.0      24         11.0
# 2016-03-10 07:15:00    13.0   10.0   10.0   10.0      24         20.0
# 2016-03-10 07:30:00    33.0   13.0   10.0   10.0      24         28.0
#
#                       day_of_week
# tpep_pickup_datetime
# 2016-03-01 00:00:00             1
# 2016-03-01 00:15:00             1
# 2016-03-01 00:30:00             1
# 2016-03-01 00:45:00             1
# 2016-03-01 01:00:00             1
# ...                           ...
# 2016-03-10 06:30:00             3
# 2016-03-10 06:45:00             3
# 2016-03-10 07:00:00             3
# 2016-03-10 07:15:00             3
# 2016-03-10 07:30:00             3
#
# [22373 rows x 7 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_percentage_error

# %%
from sklearn import set_config

set_config(transform_output="pandas")

# %%
# encode the data

encoder = ColumnTransformer([
    ("ohe", OneHotEncoder(drop="first",sparse_output=False), ["region","day_of_week"])
], remainder="passthrough", n_jobs=-1,force_int_remainder_cols=False)

# %%
encoder
# Out:
# ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                   remainder='passthrough',
#                   transformers=[('ohe',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['region', 'day_of_week'])])

# %%
# encode the train and test data

X_train_encoded = encoder.fit_transform(X_train)
X_test_encoded = encoder.transform(X_test)

# %%
# train the model

lr = LinearRegression()

# fit on the training data
lr.fit(X_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
# make predictions on the train data

y_pred_train = lr.predict(X_train_encoded)

# %%
# make predictions on the test data

y_pred_test = lr.predict(X_test_encoded)

# %%
# evaluate the baseline model

train_mape = mean_absolute_percentage_error(y_train, y_pred_train)

test_mape = mean_absolute_percentage_error(y_test, y_pred_test)

# %%
test_mape
# Out:
# 0.0022379067145746096

# %%
print(f"MAPE on trainset is {(train_mape * 100):.2f}%")
print(f"MAPE on testset is {(test_mape * 100):.2f}%")
# Out:
# MAPE on trainset is 0.41%
# MAPE on testset is 0.22%
